# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd .read_csv("RELIANCE.NS Final.csv")
data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  1996-01-08  15.627340  15.638945  14.876918  15.031645   9.860063
# 1  1996-01-09  14.586807  14.853709  14.099419  14.598411   9.575879
# 2  1996-01-10  14.312168  14.656434  14.157442  14.223200   9.329758
# 3  1996-01-11  14.080079  14.737665  14.060738  14.668038   9.621552
# 4  1996-01-12  14.776346  14.888523  14.416608  14.513312   9.520061
#
#         Volume
# 0   86288584.0
# 1  179415702.0
# 2  127653926.0
# 3  189051436.0
# 4  172918416.0

# %%
data.tail(1500)
# Out:
#             Date         Open         High          Low        Close  \
# 5545  2017-12-11   913.788208   917.304871   904.971802   907.547363
# 5546  2017-12-12   907.349243   920.276672   899.473877   907.002502
# 5547  2017-12-13   908.290344   916.264709   902.148560   906.061462
# 5548  2017-12-14   910.370605   916.215210   900.216858   912.847107
# 5549  2017-12-15   922.257935   924.189636   909.082825   911.113525
# ...          ...          ...          ...          ...          ...
# 7040  2024-01-01  2580.550049  2606.850098  2573.149902  2590.250000
# 7041  2024-01-02  2585.000000  2615.000000  2573.000000  2611.699951
# 7042  2024-01-03  2610.000000  2634.000000  2577.199951  2583.300049
# 7043  2024-01-04  2588.000000  2609.850098  2579.100098  2596.649902
# 7044  2024-01-05  2602.899902  2619.850098  2598.000000  2607.699951
#
#         Adj Close      Volume
# 5545   884.996216   4980620.0
# 5546   884.464844   7283405.0
# 5547   883.547241   4221739.0
# ...

# %%
data.shape
# Out:
# (7045, 7)

# %% [markdown]
# Exploratory Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7045 entries, 0 to 7044
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7045 non-null   object
#  1   Open       7035 non-null   float64
#  2   High       7035 non-null   float64
#  3   Low        7035 non-null   float64
#  4   Close      7035 non-null   float64
#  5   Adj Close  7035 non-null   float64
#  6   Volume     7035 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 385.4+ KB

# %%
#change the datatype to date format and setting it to index
data['Date']= pd.to_datetime(data['Date'])
data= data.set_index(data['Date'])
data.drop('Date',axis=1,inplace=True)
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close       Volume
# Date
# 1996-01-08  15.627340  15.638945  14.876918  15.031645   9.860063   86288584.0
# 1996-01-09  14.586807  14.853709  14.099419  14.598411   9.575879  179415702.0
# 1996-01-10  14.312168  14.656434  14.157442  14.223200   9.329758  127653926.0
# 1996-01-11  14.080079  14.737665  14.060738  14.668038   9.621552  189051436.0
# 1996-01-12  14.776346  14.888523  14.416608  14.513312   9.520061  172918416.0

# %%
data.isna().sum()
# Out:
# Open         10
# High         10
# Low          10
# Close        10
# Adj Close    10
# Volume       10
# dtype: int64

# %%
#filling missing values
data.fillna(0,inplace =True)

# %%
data.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#datatypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7045 entries, 1996-01-08 to 2024-01-05
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       7045 non-null   float64
#  1   High       7045 non-null   float64
#  2   Low        7045 non-null   float64
#  3   Close      7045 non-null   float64
#  4   Adj Close  7045 non-null   float64
#  5   Volume     7045 non-null   float64
# dtypes: float64(6)
# memory usage: 385.3 KB

# %%
#statistical measures of data
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  7045.000000  7045.000000  7045.000000  7045.000000  7045.000000
# mean    610.579415   617.609386   602.995090   610.019750   588.928776
# std     740.298741   747.562416   732.483141   739.730425   739.675118
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      52.684254    53.442410    51.987984    52.514053    41.031502
# 50%     418.037415   423.337189   413.109131   417.542114   385.743225
# 75%     643.896484   653.802612   633.173157   643.896484   588.528687
# max    2856.149902  2856.149902  2797.000000  2841.850098  2831.846680
#
#              Volume
# count  7.045000e+03
# mean   2.820043e+07
# std    4.780552e+07
# min    0.000000e+00
# 25%    6.499781e+06
# 50%    1.177363e+07
# 75%    2.964739e+07
# max    6.686620e+08

# %%
#closing price plotting over the years
data['Close'].plot(figsize=(14,8))
plt.title("Closing price of Reliance over the years",size=30)
plt.xlabel("Years",size=30)
plt.ylabel("Price",size=30)
# Out:
# Text(0, 0.5, 'Price')

# %%
#outlier detection
plt.figure(figsize=(8,4))
sns.set(font_scale=1.5, style="whitegrid")
sns.boxplot(data=data)
plt.show()

# %%
#calculating percentage change with respect to Adjusted close over the years
data['Adj Close'].pct_change().plot(figsize=(20,8))
plt.title("Percentage change with respect to Adjusted close over the years",size=30,pad=20)
plt.xlabel("Years",size=30)
plt.ylabel("Price",size=30)
# Out:
# Text(0, 0.5, 'Price')

# %%
#Calculating quarterly average
data.resample(rule='QS').mean()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-01-01    15.829580    16.207692    15.455981    15.822360    10.378732
# 1996-04-01    18.277621    18.519291    17.990068    18.231798    12.156839
# 1996-07-01    15.856675    16.195490    15.540951    15.819927    10.808186
# 1996-10-01    14.864669    15.098165    14.640492    14.871116    10.159958
# 1997-01-01    20.510884    20.847474    20.161239    20.485016    13.995379
# ...                 ...          ...          ...          ...          ...
# 2023-01-01  2382.592730  2399.484655  2355.924210  2375.892744  2367.529565
# 2023-04-01  2452.750822  2466.149166  2435.359998  2450.717513  2442.090942
# 2023-07-01  2519.876984  2540.652371  2498.034939  2518.769841  2513.831617
# 2023-10-01  2385.991679  2400.955823  2372.109159  2386.280827  2386.280827
# 2024-01-01  2593.289990  2617.110059  2580.089990  2597.919971  2597.919971
#
#                   Volume
# Date
# ...

# %%
#plotting quarterly mean of both high and low
data.resample(rule='QS').mean()[['High','Low']].plot(figsize=(8,4))
plt.title("Quarterly mean of both high and low",size=30,pad=20)
plt.xlabel("Years",size=30)
plt.ylabel("Price",size=30)
# Out:
# Text(0, 0.5, 'Price')

# %%
data.resample(rule='QS').mean()[['High','Low']].plot(figsize=(20,8),kind='bar')
plt.tight_layout()
plt.title("Quarterly mean bar of both high and low",size=40,pad=20)
plt.xlabel("Years",size=40)
plt.ylabel("Price",size=40)
plt.show()

# %%
data1=pd.DataFrame(data['Close'])
data1.head()
# Out:
#                 Close
# Date
# 1996-01-08  15.031645
# 1996-01-09  14.598411
# 1996-01-10  14.223200
# 1996-01-11  14.668038
# 1996-01-12  14.513312

# %% [markdown]
# # Moving Average

# %%
#moving Average
data['Close'].rolling(10).mean()
# Out:
# Date
# 1996-01-08            NaN
# 1996-01-09            NaN
# 1996-01-10            NaN
# 1996-01-11            NaN
# 1996-01-12            NaN
#                  ...
# 2024-01-01    2567.950024
# 2024-01-02    2577.020020
# 2024-01-03    2579.540015
# 2024-01-04    2586.490015
# 2024-01-05    2591.005005
# Name: Close, Length: 7045, dtype: float64

# %%
#plotting
plt.figure(figsize=(24,7))
data.Close.plot(label="org")
for i in range(2,30,6):
    data['Close'].rolling(i).mean().plot(label=str(i))
plt.title("Moving Average for 6 days " ,size=45)
plt.xlabel("years",size=30)
plt.ylabel("Average",size=30)    
plt.legend(loc='best')

# %%
#decomposing the data seasonally

import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.api import seasonal_decompose

graph=seasonal_decompose(data1.Close,period=365,extrapolate_trend=0,two_sided=True)
graph.plot()

plt.show()

# %% [markdown]
# # ARIMA Model

# %%
# Stationarity

from statsmodels.tsa.api import adfuller

# HO---> The data is not stationary.
# H1---> The data is stationary.

def test(df):
   result= adfuller( df)
   print("statistical value = ",result[0])
   print("p_value = ",result[1])

   if(result[1]<= 0.5):
      print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
   else:
      print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
test(data1['Close'])
# Out:
# statistical value =  0.8445840276070755
# p_value =  0.9923227945418458
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
data1['Close_df1']= data1['Close'] - data1['Close'].shift(1)
data1.head()
# Out:
#                 Close  Close_df1
# Date
# 1996-01-08  15.031645        NaN
# 1996-01-09  14.598411  -0.433234
# 1996-01-10  14.223200  -0.375211
# 1996-01-11  14.668038   0.444838
# 1996-01-12  14.513312  -0.154726

# %%
data1['Close_df1'].fillna(0,inplace=True)

# %%
test(data1['Close_df1'])
# Out:
# statistical value =  -48.79078668497216
# p_value =  0.0
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
data1['Close_df2']= data1['Close'] - data1['Close'].shift(2)
data1.head()
# Out:
#                 Close  Close_df1  Close_df2
# Date
# 1996-01-08  15.031645   0.000000        NaN
# 1996-01-09  14.598411  -0.433234        NaN
# 1996-01-10  14.223200  -0.375211  -0.808445
# 1996-01-11  14.668038   0.444838   0.069627
# 1996-01-12  14.513312  -0.154726   0.290112

# %%
data1['Close_df2'].fillna(0,inplace=True)

# %%
test(data1['Close_df2'])
# Out:
# statistical value =  -15.103612891493963
# p_value =  7.876292613515993e-28
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
data1['Close_df12']= data1['Close'] - data1['Close'].shift(12)
data1.head()
# Out:
#                 Close  Close_df1  Close_df2  Close_df12
# Date
# 1996-01-08  15.031645   0.000000   0.000000         NaN
# 1996-01-09  14.598411  -0.433234   0.000000         NaN
# 1996-01-10  14.223200  -0.375211  -0.808445         NaN
# 1996-01-11  14.668038   0.444838   0.069627         NaN
# 1996-01-12  14.513312  -0.154726   0.290112         NaN

# %%
data1['Close_df12'].fillna(0,inplace=True)

# %%
test(data1['Close_df12'])
# Out:
# statistical value =  -16.17446161957629
# p_value =  4.330600861846104e-29
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True,figsize=(14,8))
axes[0, 0].plot(data1.Close); axes[0, 0].set_title('Original Series')
plot_acf(data1.Close, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(data1.Close_df1.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(data1.Close_df1.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(data1.Close_df2.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(data1.Close_df2.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plt.figure(figsize=(16,10))
plot_acf(data1['Close_df2'],alpha=0.05)
plt.show()

# %%
plt.figure(figsize=(16,10))
PACF= plot_pacf(data1['Close_df2'], alpha=0.050)
plt.show()

# %%
#d=2,p=2,q=2

# %%
#separate out a validation dataset

split_point = len(data1['Close']) - 2000

dataset= data1['Close'][0:split_point]
validation= data1['Close'][split_point:]

print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', header=True)
validation.to_csv('validation.csv', header=False)

dataset= pd.read_csv("dataset.csv")
dataset.drop('Date',axis=1,inplace=True)
print(dataset.head())

validation= pd.read_csv("validation.csv",names=['Date','Close'])
validation.drop('Date',axis=1,inplace=True)
validation.head()
# Out:
# Dataset 5045, Validation 2000
#        Close
# 0  15.031645
# 1  14.598411
# 2  14.223200
# 3  14.668038
# 4  14.513312
#         Close
# 0  484.012054
# 1  478.192230
# 2  471.555115
# 3  466.032471
# 4  453.649841

# %% [markdown]
# # ARIMA Model

# %%
#using stats model

from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")


rmse=[]
p_val=[]
d_val=[]
q_val=[]


for p in range(0,3,1):
   for d in range(0,3,1):
      for q in range(0,3,1):

         model= ARIMA(dataset,order= (p,d,q))
         model=model.fit()
         print(model.summary())
         predict= model.predict(start=validation.index[0],end= validation.index[-1])
         score=np.sqrt(mean_squared_error(predict,validation))
         print("The RMSE value for p d and q", (p,d,q),'is',score)
         rmse.append(score)
         p_val.append(p)
         d_val.append(d)
         q_val.append(q)

rmse_values= pd.DataFrame()
rmse_values['RMSE']=list(rmse)
rmse_values['p']=list(p_val)
rmse_values['d']=list(d_val)
rmse_values['q']=list(q_val)
rmse_values.head()
rmse_values.sort_values(by='RMSE',ascending=True,inplace=True)
rmse_values
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 5045
# Model:                          ARIMA   Log Likelihood              -34113.954
# Date:                Sun, 28 Jan 2024   AIC                          68231.908
# Time:                        21:07:10   BIC                          68244.961
# Sample:                             0   HQIC                         68236.481
#                                - 5045
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        236.2817      3.388     69.750      0.000     229.642     242.921
# sigma2      4.375e+04   1910.604     22.899      0.000       4e+04    4.75e+04
# ...
# Ljung-Box (L1) (Q):                4983.53   Jarque-Bera (JB):               554.70
# ...

# %%
model=ARIMA(data1['Close'],order=(0,0,0))
model=model.fit()
forecast_values = model.forecast(15,alpha=0.05)
print(model.summary())
#print(forecast_values)
forecast_values.to_csv('forecast_values.csv', header=True)
forecast_values= pd.read_csv("forecast_values.csv")
forecast_values

dates = pd.date_range(start="2024-01-05", periods=len(forecast_values), freq="D")
forecast_values['dates']= pd.Series(dates)
forecast_values['dates']=pd.to_datetime(forecast_values['dates'])
forecast_values.drop("Unnamed: 0",axis=1,inplace=True)
forecast_values=forecast_values.set_index(forecast_values['dates'])

split_point=len(data1['Close']) - 2000
plt.figure(figsize=(10,5), dpi=100)
plt.plot(data1['Close'][0:split_point], label='training data')
plt.plot(data1['Close'][split_point:], color = 'green', label='Actual Stock Price')
plt.plot(forecast_values['predicted_mean'], color = 'orange',label='Predicted Stock Price')
plt.legend()
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                 7045
# Model:                          ARIMA   Log Likelihood              -56537.207
# Date:                Sun, 28 Jan 2024   AIC                         113078.414
# Time:                        21:08:01   BIC                         113092.134
# Sample:                             0   HQIC                        113083.140
#                                - 7045
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        610.0196     17.315     35.231      0.000     576.083     643.956
# sigma2      5.467e+05   1.41e+04     38.885      0.000    5.19e+05    5.74e+05
# ...
# Ljung-Box (L1) (Q):                7032.05   Jarque-Bera (JB):              3392.07
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

# report performance

split_point=len(data1['Close']) - 15
mse = mean_squared_error(data1['Close'][split_point:], forecast_values['predicted_mean'])
print('MSE: '+str(mse))
mae = mean_absolute_error(data1['Close'][split_point:], forecast_values['predicted_mean'])
print('MAE: '+str(mae))
rmse = np.sqrt(mean_squared_error(data1['Close'][split_point:], forecast_values['predicted_mean']))
print('RMSE: '+str(rmse))
mape = mean_absolute_percentage_error(data1['Close'][split_point:], forecast_values['predicted_mean'])
print('MAPE: '+str(mape))
Arima=[3848998.4067747197,1961.6103671657454,1961.8864408458303,0.7627494026925177]
# Out:
# MSE: 3848998.4067747197
# MAE: 1961.6103671657454
# RMSE: 1961.8864408458303
# MAPE: 0.7627494026925177

# %% [markdown]
# # Auto ARIMA/SARIMAX with seasonality

# %%
from pmdarima.arima import auto_arima
import math
shape=data1.shape[0]
df= data1[['Close']]
train= df.iloc[:math.ceil(shape*0.80)]
test= df.iloc[math.ceil(shape*0.80):]

# %%
model1= auto_arima(train,start_p=0,
                   start_q=0,
                   max_p=2,
                   max_q=2,
                   d=1,D=1,
                   information_criterion='aic',
                   seasonal=True,m=12,
                   suppress_warnings=True,
                   trace=True)
model1=model1.fit(train)
forecast_values= model1.predict(n_periods=15)
print(model1.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=inf, Time=9.37 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=54765.616, Time=0.37 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=51863.093, Time=2.76 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=10.44 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=53530.298, Time=0.51 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=51275.952, Time=7.65 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=22.10 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=18.03 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=52458.752, Time=8.71 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=50986.987, Time=15.99 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=51528.295, Time=6.19 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=inf, Time=27.87 sec

# %%
model=auto_arima(data1['Close'],order=(2,1,1))
model=model.fit(test)
predicted_values = model.predict(30,alpha=0.05)
print(model.summary())
print(predicted_values)

# %%
predicted_mean=[2609.909291,2611.136386,2612.326109,2613.488109,2614.657693,2615.823658,2616.991120,2618.157943,2619.325037,2620.492016,2621.659044,2622.826051,2623.993066,2625.160078,2626.327092,2627.494105,2628.661118,2629.828131,2630.995144,2632.162158,2633.329171,2634.496184,2635.663197,2636.830210,2637.997223,2639.164236,2640.331250,2641.498263,2642.665276,2643.832289]

split_point=len(data1) - 30
training_data=data1[0:split_point]
testing_data=data1[split_point:]
plt.figure(figsize=(10,5), dpi=100)
plt.plot(training_data['Close'], label='training data')
plt.plot(testing_data['Close'], color = 'green', label='Actual Stock Price')
testing_data['forecast_val']= predicted_mean
testing_data[['Close','forecast_val']]
plt.plot(testing_data['forecast_val'],label='Forecasted',color='red')
#plt.plot(forecast_values, color = 'orange',label='Predicted Stock Price')
plt.legend(loc= 'upper left')
testing_data

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

# report performance

split_point=len(data1['Close']) - 15
mse = mean_squared_error(data1['Close'][split_point:], forecast_values)
print('MSE: '+str(mse))
mae = mean_absolute_error(data1['Close'][split_point:], forecast_values)
print('MAE: '+str(mae))
rmse = np.sqrt(mean_squared_error(data1['Close'][split_point:], forecast_values))
print('RMSE: '+str(rmse))
mape = mean_absolute_percentage_error(data1['Close'][split_point:], forecast_values)
print('MAPE: '+str(mape))
Auto_arima=[2665463.3460678696,1632.3531002037262,1632.6246800988492,0.6347110431223922]

# %% [markdown]
# # LSTM Model

# %%
# Create a new dataframe with only the 'Close column
data = data1.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data

# %%
# Create the training data set
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()

# Convert the x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
import warnings
warnings.filterwarnings("ignore")

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#train the model
model.fit(x_train,y_train,epochs=30,batch_size=64,verbose=1)

# %%
# Create the testing data set
# Create a new array containing scaled values
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# %%
# Get the models predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid[['Predictions']] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid['Close'],color='green')
plt.plot(valid['Predictions'],color='red')
plt.legend(['Train', 'Val', 'Predictions'], loc='upper left')
plt.show()

# %%
# report performance

mse = mean_squared_error(predictions,y_test)
print('MSE: '+str(mse))
mae = mean_absolute_error(predictions,y_test)
print('MAE: '+str(mae))
rmse = np.sqrt(mean_squared_error(predictions,y_test))
print('RMSE: '+str(rmse))
mape = mean_absolute_percentage_error(predictions,y_test)
print('MAPE: '+str(mape))
lstm=[1751.197829211878,33.37954641042259,41.84731567510487,0.0133706256692936]

# %% [markdown]
# # Prophet Model

# %%
from prophet import Prophet

# %%
pro_data= pd.read_csv("RELIANCE.NS Final.csv")
pro_data

# %%
pro_data.drop(columns=['Open','High','Low','Adj Close','Volume'],axis=1,inplace=True)
pro_data

# %%
pro_data.fillna(0,inplace=True)

# %%
pro_data= pro_data.rename(columns={'Date':'ds','Close':'y'})

# %%
pro_data['Date']= pd.to_datetime('19960108',format='%Y%m%d' )

# %%
# Initialize the Prophet model
model2_prophet = Prophet(interval_width=0.95)

# %%
model2_prophet.fit(pro_data)

# %%
# Forecasting for 3 years
future_df=model2_prophet.make_future_dataframe(periods=30,freq='MS' )
forecast= model2_prophet.predict(future_df)
forecast

# Visualization
plt.figure(figsize=(18, 6))
model2_prophet.plot(forecast, xlabel = 'Date', ylabel = 'Close price')
plt.title('Forecasting of Close price for next 3 years')
plt.show()

# %%
y_true = pro_data['y'].values
y_pred = forecast['yhat'][:-30].values

# %%
print(forecast)

# %%
# report performance

mse = mean_squared_error(y_true,y_pred)
print('MSE: '+str(mse))
mae = mean_absolute_error(y_true,y_pred)
print('MAE: '+str(mae))
rmse = np.sqrt(mean_squared_error(y_true,y_pred))
print('RMSE: '+str(rmse))
mape = mean_absolute_percentage_error(y_true,y_pred)
print('MAPE: '+str(mape))

Prophet=[11563.1644,56.9566,107.5321,561091783752187]

# %%
Prophet=[11563.164482130642,56.956674034777805,107.53215557278968,561091783752187.0]
lstm=[1751.197829211878,33.37954641042259,41.84731567510487,0.0133706256692936]
Auto_arima=[2665463.3460678696,1632.3531002037262,1632.6246800988492,0.6347110431223922]
Arima=[3848998.4067747197,1961.6103671657454,1961.8864408458303,0.7627494026925177]
metric_df= pd.DataFrame(index=['MSE','MAE','RMSE',"MAPE"])
metric_df['Arima']= Arima
metric_df['Auto_arima']= Auto_arima
metric_df['lstm']= lstm
metric_df['Prophet']= Prophet
metric_df

# %% [markdown]
# #Deployment

# %%
# !streamlit run appupdated.py

# %%
# !pip install streamlit

# %%
import pickle
pickle_out = open("model.pkl","wb")
pickle.dump(model, pickle_out)
pickle_out.close()

# %%
dump()
